# %% [markdown]
# # Processing of Slocum Glider-AD2CP Data: RU29 2020
#
# jgradone@marine.rutgers.edu     03/10/2022    Initial <br>
# jgradone@marine.rutgers.edu     06/16/2022    Update for pre-processing <br>
#
# **This Jupyter Notebook is intended to:**<br>
# 1) Read glider data frome ERDDAP <br>
# 2) Read in AD2CP data that has been pre-processed <br>
# 3) Least squares linear inversion on ADCP velocities referenced to true ocean velocity through a depth averaged urrent constraint <br>
# 4) Save output from each segment<br>
#
# *Details/comments on what the functions are actually doing in the source code*

# %%
# Imports
import scipy.interpolate as interp
from scipy.sparse.linalg import lsqr
import scipy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import netCDF4 as nc
import math
import datetime
import xarray as xr
import matplotlib.dates as mdates
import dask.array as da
from erddapy import ERDDAP
from netCDF4 import Dataset
import gsw
import cmocean.cm as cmo
import sys
from datetime import datetime


## To import functions from Slocum-AD2CP GitHub repository, make this path the path to where the repo exists locally
sys.path.insert(0,'/home/jg1200/GitHub/Slocum-AD2CP/src/analysis/')
sys.path.insert(0,'/home/jg1200/GitHub/Slocum-AD2CP/src/data/')
from make_dataset import inversion, shear_method
from analysis import get_erddap_dataset

# %% [markdown]
# ## Step 1: Load glider data

# %%
ds_id = 'ru29-20200908T1623-trajectory-raw-delayed'

## Load flight data
variables = ['depth', 'latitude', 'longitude', 'time', 'sci_water_temp', 'sci_water_cond','source_file', 'm_water_vx', 'm_water_vy', 'm_heading']
gdf = get_erddap_dataset(ds_id, server='http://slocum-data.marine.rutgers.edu/erddap', variables = variables, filetype='dataframe')
gdf.columns = variables

## Great way to find start and end times!!
start_times = gdf.groupby('source_file').first().time.values
end_times   = gdf.groupby('source_file').last().time.values
## Remove time zone for slicing ad2cp times
start_times2 = pd.to_datetime(start_times).tz_localize(None)
end_times2 = pd.to_datetime(end_times).tz_localize(None)

gdf
# Out:
#            depth   latitude  longitude                     time  \
# 0        0.00000  18.175290 -64.802942  2020-09-08T16:23:40.15Z
# 1        0.00000  18.175290 -64.802942  2020-09-08T16:23:47.43Z
# 2            NaN  18.175290 -64.802942  2020-09-08T16:23:47.56Z
# 3            NaN  18.175290 -64.802942  2020-09-08T16:24:48.43Z
# 4            NaN  18.176045 -64.804093  2020-09-08T16:25:14.45Z
# ...          ...        ...        ...                      ...
# 5087216  0.18886  18.139090 -64.784373  2020-11-12T07:31:32.76Z
# 5087217  0.18886  18.139090 -64.784373  2020-11-12T07:31:34.77Z
# 5087218  0.14910  18.139090 -64.784373  2020-11-12T07:31:36.79Z
# 5087219  0.15904  18.139090 -64.784373  2020-11-12T07:31:38.80Z
# 5087220  0.16898  18.139090 -64.784373  2020-11-12T07:31:40.82Z
#
#          sci_water_temp  sci_water_cond                      source_file  \
# 0                0.0000         0.00000  ru29-2020-251-4-0-mbd(04270000)
# 1                0.0000         0.00000  ru29-2020-251-4-0-mbd(04270000)
# 2                   NaN             NaN  ru29-2020-251-4-0-mbd(04270000)
# 3                   NaN             NaN  ru29-2020-251-4-0-mbd(04270000)
# 4                   NaN             NaN  ru29-2020-251-4-0-mbd(04270000)
# ...                 ...             ...                              ...
# 5087216         27.6073         5.43973  ru29-2020-315-0-9-mbd(04470009)
# 5087217         27.6072         5.43980  ru29-2020-315-0-9-mbd(04470009)
# 5087218         27.6093         5.43990  ru29-2020-315-0-9-mbd(04470009)
# 5087219         27.6093         5.43993  ru29-2020-315-0-9-mbd(04470009)
# 5087220         27.6088         5.43985  ru29-2020-315-0-9-mbd(04470009)
#
#          m_water_vx  m_water_vy  m_heading
# 0               NaN         NaN        NaN
# 1               NaN         NaN        NaN
# 2               NaN         NaN    1.80293
# 3               NaN         NaN    1.80293
# 4               NaN         NaN        NaN
# ...             ...         ...        ...
# 5087216         NaN         NaN        NaN
# 5087217         NaN         NaN        NaN
# 5087218         NaN         NaN        NaN
# 5087219         NaN         NaN        NaN
# 5087220         NaN         NaN        NaN
#
# [5087221 rows x 10 columns]

# %% [markdown]
# ## Step 2: Load in AD2CP data frame

# %%
path = '/scratch/jg1200/Data/GliderData/RU29/RU29_2020/Pre_Processed/'
files = np.sort(glob.glob(path+'*.nc'))
tot_ad2cp = xr.open_mfdataset(files, concat_dim="time", combine="nested")
## Because files are not necessarily read in time order with above line
tot_ad2cp = tot_ad2cp.sortby('time')
tot_ad2cp
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 11580371, VelocityRange: 40)
# Coordinates:
#   * time           (time) datetime64[ns] 2020-09-08T17:52:48.032099072 ... 20...
#   * VelocityRange  (VelocityRange) float32 0.7 1.2 1.7 2.2 ... 19.2 19.7 20.2
# Data variables:
#     UVelocity      (VelocityRange, time) float64 dask.array<chunksize=(40, 150080), meta=np.ndarray>
#     VVelocity      (VelocityRange, time) float64 dask.array<chunksize=(40, 150080), meta=np.ndarray>
#     WVelocity      (VelocityRange, time) float64 dask.array<chunksize=(40, 150080), meta=np.ndarray>
#     Heading        (time) float32 dask.array<chunksize=(150080,), meta=np.ndarray>
#     Pressure       (time) float64 dask.array<chunksize=(150080,), meta=np.ndarray>
# Attributes: (12/350)
#     exportRevision:                               4421
#     File_ins_runTime:                             377235750.0
#     File_ins_runTime_description:                 Length of time data was col...
#     File_ins_name:                                AD2CPRaw
#     File_ins_name_description:                    Name of instrument
#     File_ins_typeName:
#     ...                                           ...
#     instrumentOffsetTime:                         0.0
#     instrumentOffsetTime_description:             Offset from instrument time...
#     timeZoneOffset:                               -14400
#     timeZoneOffset_description:                   Offset of platform local ti...
#     instrumentOffsetTimeMatlab:                   0.0
#     instrumentOffsetTimeMatlab_description:       Offset from instrument time...

# %% [markdown]
# ## Steps 3-10: Big loop to process velocity data and save output

# %%
# AD2CP only on starting on segment 408 and off after segment 976
for x in np.arange(408,978):
    ## Subset glider df to one segment
    subsetgdf = gdf[(gdf.time >= start_times[x]) & (gdf.time <= end_times[x])]
    ## Pull out last non-NaN DAC
    ind         = np.argwhere(np.isnan(subsetgdf.m_water_vx).ravel()==False).flatten()
    
    ## Check if there is a DAC, if not continue onto next segment.
    if len(ind) > 0:
        vx          = subsetgdf.m_water_vx.iloc[ind[-1]]
        vy          = subsetgdf.m_water_vy.iloc[ind[-1]]
        
        ## Pull out last non-NaN lat/lon
        ind1         = np.argwhere(np.isnan(subsetgdf.longitude).ravel()==False).flatten()   
        vx_start_lon = subsetgdf.longitude.iloc[ind1[0]]
        vx_start_lat = subsetgdf.latitude.iloc[ind1[0]]
        vx_end_lon   = subsetgdf.longitude.iloc[ind1[-1]]
        vx_end_lat   = subsetgdf.latitude.iloc[ind1[-1]]
        ## Not using the index here because I want the segment start and end times
        vx_start_tm  = subsetgdf.time.iloc[0]
        vx_end_tm    = subsetgdf.time.iloc[-1]

        ## Check is glider has a max depth greater than 10 meters. If not, continue to next segment.
        ## This is needed because the glider opens and closes a log file at the surface while sending data and
        ## so indexing by unique file names gives a segment with just surface data (which we don't want).
        if subsetgdf.depth.max() < 10:
            continue

        ## Subset AD2CP dataframe based on segment start and end times
        #ad2cp_time_ind = np.where((tot_ad2cp.time >= start_times2[x]) & (tot_ad2cp.time <= end_times2[x]))[0]
        #subset_ad2cp = tot_ad2cp.sel(time=tot_ad2cp.time.values[ad2cp_time_ind])
        ad2cp_time_ind = np.where((tot_ad2cp.time.values >= start_times2[x]) & (tot_ad2cp.time.values <= end_times2[x]))[0]
        if len(ad2cp_time_ind) > 0:

            subset_ad2cp = tot_ad2cp.sel(time= slice(tot_ad2cp.time.values[ad2cp_time_ind[0]],tot_ad2cp.time.values[ad2cp_time_ind[-1]]))

            ## Just check if there is still data after the subsetting 
            if len(subset_ad2cp.time) > 0:
                # ## Now ready for inversion!
                dz=10
                O_ls, G_ls, bin_new,obs_per_bin  = inversion(U=subset_ad2cp.UVelocity.values,V=subset_ad2cp.VVelocity.values,dz=dz,u_daverage=vx,v_daverage=vy,bins = subset_ad2cp['VelocityRange'].values, depth = subset_ad2cp['Pressure'].values,wDAC=5, wSmoothness=1)
                now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
                print("Finished Inversion", x ,"out of",len(start_times),"at" ,now)

                ###############################################
                #             Save master dataset             #
                ###############################################
                fname = "/home/jg1200/Data/GliderData/RU29/RU29_2020_AD2CP_NC/Processed_{}_meter_vertical_resolution/RU29_2020_AD2CP_Processed_Segment_{}.csv".format(dz,x)

                ## Make into a dataframe to save as a CSV
                d = {'inversion_u': np.real(O_ls), 'inversion_v': np.imag(O_ls), "inversion_depth": bin_new,
                     "start_lon": np.tile(vx_start_lon,len(bin_new)), "start_lat": np.tile(vx_start_lat,len(bin_new)),
                     "end_lon": np.tile(vx_end_lon,len(bin_new)), "end_lat": np.tile(vx_end_lat,len(bin_new)),
                     "start_tm": np.tile(vx_start_tm, len(bin_new)), "end_tm": np.tile(vx_end_tm, len(bin_new)),
                     "obs_per_bin": obs_per_bin}


                df = pd.DataFrame(data=d)
                df.to_csv(fname) 
                now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
                print("Finished Writing Data", x ,"out of",len(start_times),"at" ,now)
                del subset_ad2cp
            else:
                del subset_ad2cp
# Out:
# Finished Inversion 408 out of 1081 at 06/27/22 20:33:52
# Finished Writing Data 408 out of 1081 at 06/27/22 20:33:52
# Finished Inversion 410 out of 1081 at 06/27/22 20:35:01
# Finished Writing Data 410 out of 1081 at 06/27/22 20:35:01
# Finished Inversion 412 out of 1081 at 06/27/22 20:36:09
# Finished Writing Data 412 out of 1081 at 06/27/22 20:36:09
# Finished Inversion 414 out of 1081 at 06/27/22 20:37:13
# Finished Writing Data 414 out of 1081 at 06/27/22 20:37:13
# Finished Inversion 416 out of 1081 at 06/27/22 20:38:22
# Finished Writing Data 416 out of 1081 at 06/27/22 20:38:22
# Finished Inversion 418 out of 1081 at 06/27/22 20:39:26
# Finished Writing Data 418 out of 1081 at 06/27/22 20:39:26
# Finished Inversion 421 out of 1081 at 06/27/22 20:40:28
# Finished Writing Data 421 out of 1081 at 06/27/22 20:40:28
# Finished Inversion 423 out of 1081 at 06/27/22 20:41:34
# Finished Writing Data 423 out of 1081 at 06/27/22 20:41:34
# Finished Inversion 425 out of 1081 at 06/27/22 20:42:40
# Finished Writing Data 425 out of 1081 at 06/27/22 20:42:40
# Finished Inversion 427 out of 1081 at 06/27/22 20:43:40
# Finished Writing Data 427 out of 1081 at 06/27/22 20:43:40
# Finished Inversion 429 out of 1081 at 06/27/22 20:44:36
# Finished Writing Data 429 out of 1081 at 06/27/22 20:44:36
# Finished Inversion 430 out of 1081 at 06/27/22 20:45:28
# Finished Writing Data 430 out of 1081 at 06/27/22 20:45:28
# Finished Inversion 432 out of 1081 at 06/27/22 20:46:23
# Finished Writing Data 432 out of 1081 at 06/27/22 20:46:23
# Finished Inversion 434 out of 1081 at 06/27/22 20:47:17
# Finished Writing Data 434 out of 1081 at 06/27/22 20:47:17
# Finished Inversion 436 out of 1081 at 06/27/22 20:48:15
# Finished Writing Data 436 out of 1081 at 06/27/22 20:48:15
# Finished Inversion 438 out of 1081 at 06/27/22 20:49:24
# Finished Writing Data 438 out of 1081 at 06/27/22 20:49:24
# Finished Inversion 440 out of 1081 at 06/27/22 20:50:27
# Finished Writing Data 440 out of 1081 at 06/27/22 20:50:27
# Finished Inversion 443 out of 1081 at 06/27/22 20:51:31
# Finished Writing Data 443 out of 1081 at 06/27/22 20:51:31
# Finished Inversion 445 out of 1081 at 06/27/22 20:52:28
# Finished Writing Data 445 out of 1081 at 06/27/22 20:52:28
# Finished Inversion 447 out of 1081 at 06/27/22 20:53:27
# Finished Writing Data 447 out of 1081 at 06/27/22 20:53:27
# Finished Inversion 449 out of 1081 at 06/27/22 20:54:22
# Finished Writing Data 449 out of 1081 at 06/27/22 20:54:22
# Finished Inversion 451 out of 1081 at 06/27/22 20:55:17
# Finished Writing Data 451 out of 1081 at 06/27/22 20:56:44
# Finished Inversion 452 out of 1081 at 06/27/22 20:57:39
# Finished Writing Data 452 out of 1081 at 06/27/22 20:57:39
# Finished Inversion 454 out of 1081 at 06/27/22 20:58:37
# Finished Writing Data 454 out of 1081 at 06/27/22 20:58:37
# Finished Inversion 456 out of 1081 at 06/27/22 20:59:34
# Finished Writing Data 456 out of 1081 at 06/27/22 20:59:34
# Finished Inversion 458 out of 1081 at 06/27/22 21:00:28
# Finished Writing Data 458 out of 1081 at 06/27/22 21:00:28
# Finished Inversion 460 out of 1081 at 06/27/22 21:01:28
# Finished Writing Data 460 out of 1081 at 06/27/22 21:01:28
# Finished Inversion 462 out of 1081 at 06/27/22 21:02:23
# Finished Writing Data 462 out of 1081 at 06/27/22 21:02:23
# Finished Inversion 465 out of 1081 at 06/27/22 21:03:29
# Finished Writing Data 465 out of 1081 at 06/27/22 21:03:29
# Finished Inversion 467 out of 1081 at 06/27/22 21:04:42
# Finished Writing Data 467 out of 1081 at 06/27/22 21:04:42
# Finished Inversion 469 out of 1081 at 06/27/22 21:05:52
# Finished Writing Data 469 out of 1081 at 06/27/22 21:05:52
# Finished Inversion 471 out of 1081 at 06/27/22 21:06:50
# Finished Writing Data 471 out of 1081 at 06/27/22 21:06:50
# Finished Inversion 473 out of 1081 at 06/27/22 21:07:48
# Finished Writing Data 473 out of 1081 at 06/27/22 21:07:48
# Finished Inversion 474 out of 1081 at 06/27/22 21:08:41
# Finished Writing Data 474 out of 1081 at 06/27/22 21:08:41
# Finished Inversion 476 out of 1081 at 06/27/22 21:08:59
# Finished Writing Data 476 out of 1081 at 06/27/22 21:08:59
# Finished Inversion 496 out of 1081 at 06/27/22 21:10:03
# Finished Writing Data 496 out of 1081 at 06/27/22 21:10:03
# Finished Inversion 500 out of 1081 at 06/27/22 21:10:15
# Finished Writing Data 500 out of 1081 at 06/27/22 21:10:15
# Finished Inversion 502 out of 1081 at 06/27/22 21:11:08
# Finished Writing Data 502 out of 1081 at 06/27/22 21:11:08
# Finished Inversion 504 out of 1081 at 06/27/22 21:11:59
# Finished Writing Data 504 out of 1081 at 06/27/22 21:11:59
# Finished Inversion 506 out of 1081 at 06/27/22 21:12:51
# Finished Writing Data 506 out of 1081 at 06/27/22 21:12:51
# Finished Inversion 509 out of 1081 at 06/27/22 21:13:42
# Finished Writing Data 509 out of 1081 at 06/27/22 21:13:42
# Finished Inversion 511 out of 1081 at 06/27/22 21:14:37
# Finished Writing Data 511 out of 1081 at 06/27/22 21:14:37
# Finished Inversion 513 out of 1081 at 06/27/22 21:15:37
# Finished Writing Data 513 out of 1081 at 06/27/22 21:15:37
# Finished Inversion 515 out of 1081 at 06/27/22 21:16:36
# Finished Writing Data 515 out of 1081 at 06/27/22 21:16:36
# Finished Inversion 517 out of 1081 at 06/27/22 21:17:40
# Finished Writing Data 517 out of 1081 at 06/27/22 21:17:40
# Finished Inversion 519 out of 1081 at 06/27/22 21:18:50
# Finished Writing Data 519 out of 1081 at 06/27/22 21:18:50
# Finished Inversion 521 out of 1081 at 06/27/22 21:19:56
# Finished Writing Data 521 out of 1081 at 06/27/22 21:19:56
# Finished Inversion 523 out of 1081 at 06/27/22 21:21:00
# Finished Writing Data 523 out of 1081 at 06/27/22 21:21:00
# Finished Inversion 525 out of 1081 at 06/27/22 21:22:02
# Finished Writing Data 525 out of 1081 at 06/27/22 21:22:02
# Finished Inversion 527 out of 1081 at 06/27/22 21:23:02
# Finished Writing Data 527 out of 1081 at 06/27/22 21:23:02
# Finished Inversion 529 out of 1081 at 06/27/22 21:24:00
# Finished Writing Data 529 out of 1081 at 06/27/22 21:24:00
# Finished Inversion 532 out of 1081 at 06/27/22 21:25:01
# Finished Writing Data 532 out of 1081 at 06/27/22 21:25:01
# Finished Inversion 534 out of 1081 at 06/27/22 21:26:00
# Finished Writing Data 534 out of 1081 at 06/27/22 21:26:00
# Finished Inversion 536 out of 1081 at 06/27/22 21:27:01
# Finished Writing Data 536 out of 1081 at 06/27/22 21:27:01
# Finished Inversion 537 out of 1081 at 06/27/22 21:27:54
# Finished Writing Data 537 out of 1081 at 06/27/22 21:27:54
# Finished Inversion 539 out of 1081 at 06/27/22 21:28:46
# Finished Writing Data 539 out of 1081 at 06/27/22 21:28:46
# Finished Inversion 541 out of 1081 at 06/27/22 21:29:56
# Finished Writing Data 541 out of 1081 at 06/27/22 21:29:56
# Finished Inversion 542 out of 1081 at 06/27/22 21:30:50
# Finished Writing Data 542 out of 1081 at 06/27/22 21:30:50
# Finished Inversion 544 out of 1081 at 06/27/22 21:31:46
# Finished Writing Data 544 out of 1081 at 06/27/22 21:31:46
# Finished Inversion 546 out of 1081 at 06/27/22 21:32:43
# Finished Writing Data 546 out of 1081 at 06/27/22 21:32:43
# Finished Inversion 548 out of 1081 at 06/27/22 21:33:50
# Finished Writing Data 548 out of 1081 at 06/27/22 21:33:50
# Finished Inversion 550 out of 1081 at 06/27/22 21:34:49
# Finished Writing Data 550 out of 1081 at 06/27/22 21:34:49
# Finished Inversion 553 out of 1081 at 06/27/22 21:35:42
# Finished Writing Data 553 out of 1081 at 06/27/22 21:35:42
# Finished Inversion 555 out of 1081 at 06/27/22 21:36:32
# Finished Writing Data 555 out of 1081 at 06/27/22 21:36:32
# Finished Inversion 557 out of 1081 at 06/27/22 21:37:22
# Finished Writing Data 557 out of 1081 at 06/27/22 21:37:22
# Finished Inversion 559 out of 1081 at 06/27/22 21:38:11
# Finished Writing Data 559 out of 1081 at 06/27/22 21:38:11
# Finished Inversion 561 out of 1081 at 06/27/22 21:39:11
# Finished Writing Data 561 out of 1081 at 06/27/22 21:39:11
# Finished Inversion 563 out of 1081 at 06/27/22 21:40:15
# Finished Writing Data 563 out of 1081 at 06/27/22 21:40:15
# Finished Inversion 564 out of 1081 at 06/27/22 21:41:15
# Finished Writing Data 564 out of 1081 at 06/27/22 21:41:15
# Finished Inversion 566 out of 1081 at 06/27/22 21:42:14
# Finished Writing Data 566 out of 1081 at 06/27/22 21:42:14
# Finished Inversion 568 out of 1081 at 06/27/22 21:43:16
# Finished Writing Data 568 out of 1081 at 06/27/22 21:43:16
# Finished Inversion 570 out of 1081 at 06/27/22 21:44:18
# Finished Writing Data 570 out of 1081 at 06/27/22 21:44:18
# Finished Inversion 572 out of 1081 at 06/27/22 21:45:23
# Finished Writing Data 572 out of 1081 at 06/27/22 21:45:56
# Finished Inversion 575 out of 1081 at 06/27/22 21:47:02
# Finished Writing Data 575 out of 1081 at 06/27/22 21:47:02
# Finished Inversion 577 out of 1081 at 06/27/22 21:48:10
# Finished Writing Data 577 out of 1081 at 06/27/22 21:48:10
# Finished Inversion 579 out of 1081 at 06/27/22 21:49:10
# Finished Writing Data 579 out of 1081 at 06/27/22 21:49:10
# Finished Inversion 581 out of 1081 at 06/27/22 21:50:05
# Finished Writing Data 581 out of 1081 at 06/27/22 21:50:05
# Finished Inversion 583 out of 1081 at 06/27/22 21:51:07
# Finished Writing Data 583 out of 1081 at 06/27/22 21:51:07
# Finished Inversion 585 out of 1081 at 06/27/22 21:52:04
# Finished Writing Data 585 out of 1081 at 06/27/22 21:52:04
# Finished Inversion 586 out of 1081 at 06/27/22 21:53:01
# Finished Writing Data 586 out of 1081 at 06/27/22 21:53:01
# Finished Inversion 588 out of 1081 at 06/27/22 21:53:55
# Finished Writing Data 588 out of 1081 at 06/27/22 21:53:55
# Finished Inversion 590 out of 1081 at 06/27/22 21:54:39
# Finished Writing Data 590 out of 1081 at 06/27/22 21:54:39
# Finished Inversion 592 out of 1081 at 06/27/22 21:55:30
# Finished Writing Data 592 out of 1081 at 06/27/22 21:55:30
# Finished Inversion 594 out of 1081 at 06/27/22 21:56:16
# Finished Writing Data 594 out of 1081 at 06/27/22 21:56:16
# Finished Inversion 597 out of 1081 at 06/27/22 21:57:17
# Finished Writing Data 597 out of 1081 at 06/27/22 21:57:17
# Finished Inversion 599 out of 1081 at 06/27/22 21:58:18
# Finished Writing Data 599 out of 1081 at 06/27/22 21:58:18
# Finished Inversion 601 out of 1081 at 06/27/22 21:59:11
# Finished Writing Data 601 out of 1081 at 06/27/22 21:59:11
# Finished Inversion 603 out of 1081 at 06/27/22 21:59:56
# Finished Writing Data 603 out of 1081 at 06/27/22 21:59:56
# Finished Inversion 605 out of 1081 at 06/27/22 22:00:48
# Finished Writing Data 605 out of 1081 at 06/27/22 22:00:48
# Finished Inversion 608 out of 1081 at 06/27/22 22:01:43
# Finished Writing Data 608 out of 1081 at 06/27/22 22:01:43
# Finished Inversion 610 out of 1081 at 06/27/22 22:02:45
# Finished Writing Data 610 out of 1081 at 06/27/22 22:02:45
# Finished Inversion 612 out of 1081 at 06/27/22 22:03:48
# Finished Writing Data 612 out of 1081 at 06/27/22 22:03:48
# Finished Inversion 614 out of 1081 at 06/27/22 22:04:50
# Finished Writing Data 614 out of 1081 at 06/27/22 22:04:50
# Finished Inversion 616 out of 1081 at 06/27/22 22:05:54
# Finished Writing Data 616 out of 1081 at 06/27/22 22:05:54
# Finished Inversion 619 out of 1081 at 06/27/22 22:06:57
# Finished Writing Data 619 out of 1081 at 06/27/22 22:06:58
# Finished Inversion 621 out of 1081 at 06/27/22 22:08:00
# Finished Writing Data 621 out of 1081 at 06/27/22 22:08:00
# Finished Inversion 623 out of 1081 at 06/27/22 22:09:03
# Finished Writing Data 623 out of 1081 at 06/27/22 22:09:03
# Finished Inversion 625 out of 1081 at 06/27/22 22:10:12
# Finished Writing Data 625 out of 1081 at 06/27/22 22:10:12
# Finished Inversion 627 out of 1081 at 06/27/22 22:11:16
# Finished Writing Data 627 out of 1081 at 06/27/22 22:11:16
# Finished Inversion 631 out of 1081 at 06/27/22 22:12:16
# Finished Writing Data 631 out of 1081 at 06/27/22 22:12:16
# Finished Inversion 633 out of 1081 at 06/27/22 22:13:14
# Finished Writing Data 633 out of 1081 at 06/27/22 22:13:14
# Finished Inversion 635 out of 1081 at 06/27/22 22:14:11
# Finished Writing Data 635 out of 1081 at 06/27/22 22:14:11
# Finished Inversion 637 out of 1081 at 06/27/22 22:15:03
# Finished Writing Data 637 out of 1081 at 06/27/22 22:15:03
# Finished Inversion 639 out of 1081 at 06/27/22 22:15:55
# Finished Writing Data 639 out of 1081 at 06/27/22 22:15:55
# Finished Inversion 642 out of 1081 at 06/27/22 22:16:47
# Finished Writing Data 642 out of 1081 at 06/27/22 22:16:47
# Finished Inversion 644 out of 1081 at 06/27/22 22:17:40
# Finished Writing Data 644 out of 1081 at 06/27/22 22:17:40
# Finished Inversion 646 out of 1081 at 06/27/22 22:18:33
# Finished Writing Data 646 out of 1081 at 06/27/22 22:18:33
# Finished Inversion 648 out of 1081 at 06/27/22 22:19:35
# Finished Writing Data 648 out of 1081 at 06/27/22 22:19:35
# Finished Inversion 650 out of 1081 at 06/27/22 22:20:30
# Finished Writing Data 650 out of 1081 at 06/27/22 22:20:30
# Finished Inversion 653 out of 1081 at 06/27/22 22:21:26
# Finished Writing Data 653 out of 1081 at 06/27/22 22:21:26
# Finished Inversion 655 out of 1081 at 06/27/22 22:22:22
# Finished Writing Data 655 out of 1081 at 06/27/22 22:22:22
# Finished Inversion 657 out of 1081 at 06/27/22 22:23:21
# Finished Writing Data 657 out of 1081 at 06/27/22 22:23:21
# Finished Inversion 659 out of 1081 at 06/27/22 22:24:15
# Finished Writing Data 659 out of 1081 at 06/27/22 22:24:15
# Finished Inversion 661 out of 1081 at 06/27/22 22:25:16
# Finished Writing Data 661 out of 1081 at 06/27/22 22:25:16
# Finished Inversion 662 out of 1081 at 06/27/22 22:26:26
# Finished Writing Data 662 out of 1081 at 06/27/22 22:26:26
# Finished Inversion 665 out of 1081 at 06/27/22 22:27:33
# Finished Writing Data 665 out of 1081 at 06/27/22 22:27:33
# Finished Inversion 667 out of 1081 at 06/27/22 22:28:40
# Finished Writing Data 667 out of 1081 at 06/27/22 22:28:40
# Finished Inversion 669 out of 1081 at 06/27/22 22:29:47
# Finished Writing Data 669 out of 1081 at 06/27/22 22:29:47
# Finished Inversion 671 out of 1081 at 06/27/22 22:30:55
# Finished Writing Data 671 out of 1081 at 06/27/22 22:30:55
# Finished Inversion 673 out of 1081 at 06/27/22 22:32:04
# Finished Writing Data 673 out of 1081 at 06/27/22 22:32:04
# Finished Inversion 675 out of 1081 at 06/27/22 22:32:32
# Finished Writing Data 675 out of 1081 at 06/27/22 22:32:32
# Finished Inversion 677 out of 1081 at 06/27/22 22:33:51
# Finished Writing Data 677 out of 1081 at 06/27/22 22:33:51
# Finished Inversion 678 out of 1081 at 06/27/22 22:34:38
# Finished Writing Data 678 out of 1081 at 06/27/22 22:34:38
# Finished Inversion 680 out of 1081 at 06/27/22 22:36:12
# Finished Writing Data 680 out of 1081 at 06/27/22 22:36:12
# Finished Inversion 682 out of 1081 at 06/27/22 22:37:53
# Finished Writing Data 682 out of 1081 at 06/27/22 22:37:53
# Finished Inversion 687 out of 1081 at 06/27/22 22:40:31
# Finished Writing Data 687 out of 1081 at 06/27/22 22:41:27
# Finished Inversion 689 out of 1081 at 06/27/22 22:42:39
# Finished Writing Data 689 out of 1081 at 06/27/22 22:42:39
# Finished Inversion 691 out of 1081 at 06/27/22 22:43:54
# Finished Writing Data 691 out of 1081 at 06/27/22 22:43:54
# Finished Inversion 693 out of 1081 at 06/27/22 22:45:23
# Finished Writing Data 693 out of 1081 at 06/27/22 22:45:23
# Finished Inversion 695 out of 1081 at 06/27/22 22:46:44
# Finished Writing Data 695 out of 1081 at 06/27/22 22:46:45
# Finished Inversion 698 out of 1081 at 06/27/22 22:47:51
# Finished Writing Data 698 out of 1081 at 06/27/22 22:47:51
# Finished Inversion 700 out of 1081 at 06/27/22 22:48:51
# Finished Writing Data 700 out of 1081 at 06/27/22 22:48:51
# Finished Inversion 702 out of 1081 at 06/27/22 22:49:46
# Finished Writing Data 702 out of 1081 at 06/27/22 22:49:46
# Finished Inversion 704 out of 1081 at 06/27/22 22:50:40
# Finished Writing Data 704 out of 1081 at 06/27/22 22:50:40
# Finished Inversion 706 out of 1081 at 06/27/22 22:51:40
# Finished Writing Data 706 out of 1081 at 06/27/22 22:51:40
# Finished Inversion 709 out of 1081 at 06/27/22 22:52:43
# Finished Writing Data 709 out of 1081 at 06/27/22 22:52:43
# Finished Inversion 711 out of 1081 at 06/27/22 22:53:46
# Finished Writing Data 711 out of 1081 at 06/27/22 22:53:46
# Finished Inversion 713 out of 1081 at 06/27/22 22:54:44
# Finished Writing Data 713 out of 1081 at 06/27/22 22:54:44
# Finished Inversion 715 out of 1081 at 06/27/22 22:55:44
# Finished Writing Data 715 out of 1081 at 06/27/22 22:55:44
# Finished Inversion 717 out of 1081 at 06/27/22 22:56:57
# Finished Writing Data 717 out of 1081 at 06/27/22 22:56:57
# Finished Inversion 720 out of 1081 at 06/27/22 22:58:13
# Finished Writing Data 720 out of 1081 at 06/27/22 22:58:13
# Finished Inversion 722 out of 1081 at 06/27/22 22:59:22
# Finished Writing Data 722 out of 1081 at 06/27/22 22:59:22
# Finished Inversion 723 out of 1081 at 06/27/22 23:00:47
# Finished Writing Data 723 out of 1081 at 06/27/22 23:00:47
# Finished Inversion 725 out of 1081 at 06/27/22 23:01:58
# Finished Writing Data 725 out of 1081 at 06/27/22 23:01:58
# Finished Inversion 727 out of 1081 at 06/27/22 23:02:59
# Finished Writing Data 727 out of 1081 at 06/27/22 23:02:59
# Finished Inversion 730 out of 1081 at 06/27/22 23:03:58
# Finished Writing Data 730 out of 1081 at 06/27/22 23:03:58
# Finished Inversion 732 out of 1081 at 06/27/22 23:04:57
# Finished Writing Data 732 out of 1081 at 06/27/22 23:04:57
# Finished Inversion 734 out of 1081 at 06/27/22 23:05:56
# Finished Writing Data 734 out of 1081 at 06/27/22 23:05:56
# Finished Inversion 736 out of 1081 at 06/27/22 23:06:58
# Finished Writing Data 736 out of 1081 at 06/27/22 23:06:58
# Finished Inversion 738 out of 1081 at 06/27/22 23:08:03
# Finished Writing Data 738 out of 1081 at 06/27/22 23:08:03
# Finished Inversion 742 out of 1081 at 06/27/22 23:09:13
# Finished Writing Data 742 out of 1081 at 06/27/22 23:09:13
# Finished Inversion 744 out of 1081 at 06/27/22 23:10:20
# Finished Writing Data 744 out of 1081 at 06/27/22 23:10:20
# Finished Inversion 746 out of 1081 at 06/27/22 23:11:09
# Finished Writing Data 746 out of 1081 at 06/27/22 23:11:09
# Finished Inversion 748 out of 1081 at 06/27/22 23:12:08
# Finished Writing Data 748 out of 1081 at 06/27/22 23:12:08
# Finished Inversion 750 out of 1081 at 06/27/22 23:13:07
# Finished Writing Data 750 out of 1081 at 06/27/22 23:13:07
# Finished Inversion 753 out of 1081 at 06/27/22 23:14:00
# Finished Writing Data 753 out of 1081 at 06/27/22 23:14:00

# %% [markdown]
# ## Do the same thing but for the shear method now

# %%
# AD2CP only on starting on segment 408 and off after segment 976
for x in np.arange(408,978):

    ## Subset glider df to one segment
    subsetgdf = gdf[(gdf.time >= start_times[x]) & (gdf.time <= end_times[x])]
    ## Pull out last non-NaN DAC
    ind         = np.argwhere(np.isnan(subsetgdf.m_water_vx).ravel()==False).flatten()
    
    ## Check if there is a DAC, if not continue onto next segment.
    if len(ind) > 0:
        vx          = subsetgdf.m_water_vx.iloc[ind[-1]]
        vy          = subsetgdf.m_water_vy.iloc[ind[-1]]
        
        ## Pull out last non-NaN lat/lon
        ind1         = np.argwhere(np.isnan(subsetgdf.longitude).ravel()==False).flatten()   
        vx_start_lon = subsetgdf.longitude.iloc[ind1[0]]
        vx_start_lat = subsetgdf.latitude.iloc[ind1[0]]
        vx_end_lon   = subsetgdf.longitude.iloc[ind1[-1]]
        vx_end_lat   = subsetgdf.latitude.iloc[ind1[-1]]
        ## Not using the index here because I want the segment start and end times
        vx_start_tm  = subsetgdf.time.iloc[0]
        vx_end_tm    = subsetgdf.time.iloc[-1]

        ## Check is glider has a max depth greater than 10 meters. If not, continue to next segment.
        ## This is needed because the glider opens and closes a log file at the surface while sending data and
        ## so indexing by unique file names gives a segment with just surface data (which we don't want).
        if subsetgdf.depth.max() < 10:
            continue

        ## Subset AD2CP dataframe based on segment start and end times
        #ad2cp_time_ind = np.where((tot_ad2cp.time >= start_times2[x]) & (tot_ad2cp.time <= end_times2[x]))[0]
        #subset_ad2cp = tot_ad2cp.sel(time=tot_ad2cp.time.values[ad2cp_time_ind])
        ad2cp_time_ind = np.where((tot_ad2cp.time.values >= start_times2[x]) & (tot_ad2cp.time.values <= end_times2[x]))[0]
        if len(ad2cp_time_ind) > 0:
            subset_ad2cp = tot_ad2cp.sel(time= slice(tot_ad2cp.time.values[ad2cp_time_ind[0]],tot_ad2cp.time.values[ad2cp_time_ind[-1]]))

            ## Just check if there is still data after the subsetting 
            if len(subset_ad2cp.time) > 0:
                ## Now process AD2CP!

                ## Now ready for shear method!!            
                dz=10
                vel_referenced, bin_centers, vel_referenced_std = shear_method(U=subset_ad2cp.UVelocity.values, V=subset_ad2cp.VVelocity.values, W=subset_ad2cp.WVelocity.values, vx=vx, vy=vy, bins = subset_ad2cp['VelocityRange'].values, depth = subset_ad2cp['Pressure'].values, dz=dz)
                now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
                print("Finished Shear Method", x ,"out of",len(start_times),"at" ,now)

                ###############################################
                #             Save master dataset             #
                ###############################################
                fname = "/home/jg1200/Data/GliderData/RU29/RU29_2020_AD2CP_NC/Processed_shear_{}_meter_vertical_resolution/RU29_2020_AD2CP_Processed_Segment_{}.csv".format(dz,x)
                ## Make into a dataframe to save as a CSV

                 # Make into a dataframe to save as a CSV
                d = {'U_shear_method': vel_referenced[:,0], 'V_shear_method': vel_referenced[:,1], "bin_new_shear": bin_centers,
                     "U_prof_std": vel_referenced_std[:,0], "V_prof_std": vel_referenced_std[:,1],
                     "start_lon": np.tile(vx_start_lon,len(bin_centers)), "start_lat": np.tile(vx_start_lat,len(bin_centers)),
                     "end_lon": np.tile(vx_end_lon,len(bin_centers)), "end_lat": np.tile(vx_end_lat,len(bin_centers)),
                     "start_tm": np.tile(vx_start_tm, len(bin_centers)), "end_tm": np.tile(vx_end_tm, len(bin_centers))}


                df = pd.DataFrame(data=d)
                df.to_csv(fname) 
                now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
                print("Finished Writing Data", x ,"out of",len(start_times),"at" ,now)
                del subset_ad2cp
            else:
                del subset_ad2cp
