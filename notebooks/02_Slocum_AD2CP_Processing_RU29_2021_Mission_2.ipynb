# %% [markdown]
# # Processing of Slocum Glider-AD2CP Data: RU29 2021 Mission 2
#
# jgradone@marine.rutgers.edu     03/10/2022    Initial
#
# **This Jupyter Notebook is intended to:**<br>
# 1) Read glider data frome ERDDAP <br>
# 2) Read in AD2CP data processed to NetCDFs using the Nortek MIDAS software as an xarray DataSet and combine all into one massive DataSet <br>
#
# **Then in a big for loop:** <br>
# 3) Pull out just one glider segment (based on a unique file name) and the corresponding dead-reckoned depth average current. Use the start and end times to subset the AD2CP data <br>
# 4) Correct for local speed of sound <br>
# 5) QAQC AD2CP data <br>
# 6) Correct beams to level true-depth <br>
# 7) Bin map AD2CP data <br>
# 8) AD2CP Coordinate transformation from beam to XYZ to ENU <br>
# 9) Least squares linear inversion on ADCP velocities referenced to true ocean velocity through a depth averaged urrent constraint <br>
# 10) Save output from each segment<br>
#
# *Details/comments on what the functions are actually doing in the source code*

# %%
# Imports
import scipy.interpolate as interp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import netCDF4 as nc
import math
import datetime
import xarray as xr
import matplotlib.dates as mdates
import dask.array as da
from erddapy import ERDDAP
from netCDF4 import Dataset
import gsw
import cmocean.cm as cmo
import sys
from datetime import datetime


## To import functions from Slocum-AD2CP GitHub repository, make this path the path to where the repo exists locally
sys.path.insert(0,'/home/jg1200/GitHub/Slocum-AD2CP/src/analysis/')
sys.path.insert(0,'/home/jg1200/GitHub/Slocum-AD2CP/src/data/')
from make_dataset import correct_sound_speed, beam_true_depth, cell_vert, binmap_adcp, beam2enu, inversion, qaqc_pre_coord_transform
from analysis import get_erddap_dataset

# %% [markdown]
# ## Step 1: Load glider data

# %%
ds_id = 'ru29-20210908T1943-trajectory-raw-delayed'

## Load flight data
variables = ['depth', 'latitude', 'longitude', 'time', 'sci_water_temp', 'sci_water_cond','source_file', 'm_water_vx', 'm_water_vy', 'm_heading']
gdf = get_erddap_dataset(ds_id, server='http://slocum-data.marine.rutgers.edu/erddap', variables = variables, filetype='dataframe')
gdf.columns = variables

## Great way to find start and end times!!
start_times = gdf.groupby('source_file').first().time.values
end_times   = gdf.groupby('source_file').last().time.values
## Remove time zone for slicing ad2cp times
start_times2 = pd.to_datetime(start_times).tz_localize(None)
end_times2 = pd.to_datetime(end_times).tz_localize(None)

gdf

# x=10
# plt.plot(gdf.depth[(gdf.time >= start_times[x]) & (gdf.time <= end_times[x])])
# Out:
#          depth   latitude  longitude                     time  sci_water_temp  \
# 0          0.0  18.172288 -64.968623  2021-09-08T19:43:16.84Z             0.0
# 1          NaN  18.172288 -64.968623  2021-09-08T19:43:22.01Z             NaN
# 2          0.0  18.172288 -64.968623  2021-09-08T19:43:23.84Z             0.0
# 3          NaN  18.172288 -64.968623  2021-09-08T19:44:26.30Z             NaN
# 4          NaN  18.172270 -64.968681  2021-09-08T19:44:52.37Z             NaN
# ...        ...        ...        ...                      ...             ...
# 1453164    NaN        NaN        NaN  2021-10-07T19:57:17.47Z             NaN
# 1453165    NaN        NaN        NaN  2021-10-07T19:57:23.31Z             NaN
# 1453166    NaN        NaN        NaN  2021-10-07T19:57:30.35Z             NaN
# 1453167    NaN        NaN        NaN  2021-10-07T19:57:34.80Z             NaN
# 1453168    NaN        NaN        NaN  2021-10-07T19:57:38.77Z             NaN
#
#          sci_water_cond                      source_file  m_water_vx  \
# 0                   0.0  ru29-2021-250-3-0-dbd(05900000)         NaN
# 1                   NaN  ru29-2021-250-3-0-dbd(05900000)         0.0
# 2                   0.0  ru29-2021-250-3-0-dbd(05900000)         NaN
# 3                   NaN  ru29-2021-250-3-0-dbd(05900000)         0.0
# 4                   NaN  ru29-2021-250-3-0-dbd(05900000)         NaN
# ...                 ...                              ...         ...
# 1453164             NaN  ru29-2021-279-2-0-dbd(06020000)         NaN
# 1453165             NaN  ru29-2021-279-2-0-dbd(06020000)         NaN
# 1453166             NaN  ru29-2021-279-2-0-dbd(06020000)         NaN
# 1453167             NaN  ru29-2021-279-2-0-dbd(06020000)         NaN
# 1453168             NaN  ru29-2021-279-2-0-dbd(06020000)         NaN
#
#          m_water_vy  m_heading
# 0               NaN        NaN
# 1               0.0    1.77675
# 2               NaN        NaN
# 3               0.0    1.77675
# 4               NaN        NaN
# ...             ...        ...
# 1453164         NaN        NaN
# 1453165         NaN        NaN
# 1453166         NaN        NaN
# 1453167         NaN        NaN
# 1453168         NaN        NaN
#
# [1453169 rows x 10 columns]

# %% [markdown]
# ## Step 2: Load in AD2CP data frame

# %%
path = '/home/jg1200/Data/GliderData/RU29/RU29_2021_Mission_2_AD2CP_NC/'
files = np.sort(glob.glob(path+'*.nc'))

tot_ad2cp = xr.open_mfdataset(files,group='Data/Burst/', concat_dim="time", combine="nested")
## I think this is a documented bug in the xarray open_mfdataset function for grouped NetCDFs
config = xr.open_dataset(files[0],group='Config')
## So, just assigning the global attributes from the first file to the combined file
tot_ad2cp = tot_ad2cp.assign_attrs(config.attrs)
tot_ad2cp = tot_ad2cp.rename({'Velocity Range':'VelocityRange','Correlation Range':'CorrelationRange','Amplitude Range':'AmplitudeRange'})
# 2 House-keeping steps
# 1) Roll shifted 180 for some reason
tot_ad2cp['Roll'] = tot_ad2cp['Roll']-180
# 2) Surface depth is 10 meters. Needed for at least for the 2020 and both 2021 deployments, per conversations with Sven from Nortek.
tot_ad2cp['Pressure'] = tot_ad2cp['Pressure']-10
# Put time on x-dimension
tot_ad2cp = tot_ad2cp.transpose()
tot_ad2cp
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 9192584, VelocityRange: 40, CorrelationRange: 40, AmplitudeRange: 40, Physicalbeam_dim: 4, AHRSRotationMatrix_dim: 9)
# Coordinates:
#   * time                       (time) datetime64[ns] 2021-10-04T12:52:51.9070...
#   * VelocityRange              (VelocityRange) float32 0.7 1.2 1.7 ... 19.7 20.2
#   * CorrelationRange           (CorrelationRange) float32 0.7 1.2 ... 19.7 20.2
#   * AmplitudeRange             (AmplitudeRange) float32 0.7 1.2 ... 19.7 20.2
# Dimensions without coordinates: Physicalbeam_dim, AHRSRotationMatrix_dim
# Data variables: (12/52)
#     VelocityBeam1              (VelocityRange, time) float32 dask.array<chunksize=(40, 148123), meta=np.ndarray>
#     VelocityBeam2              (VelocityRange, time) float32 dask.array<chunksize=(40, 148123), meta=np.ndarray>
#     VelocityBeam3              (VelocityRange, time) float32 dask.array<chunksize=(40, 148123), meta=np.ndarray>
#     VelocityBeam4              (VelocityRange, time) float32 dask.array<chunksize=(40, 148123), meta=np.ndarray>
#     CorrelationBeam1           (CorrelationRange, time) float32 dask.array<chunksize=(40, 148123), meta=np.ndarray>
#     CorrelationBeam2           (CorrelationRange, time) float32 dask.array<chunksize=(40, 148123), meta=np.ndarray>
#     ...                         ...
#     QuaternionX                (time) float32 dask.array<chunksize=(148123,), meta=np.ndarray>
#     QuaternionY                (time) float32 dask.array<chunksize=(148123,), meta=np.ndarray>
#     QuaternionZ                (time) float32 dask.array<chunksize=(148123,), meta=np.ndarray>
#     AHRSGyroX                  (time) float32 dask.array<chunksize=(148123,), meta=np.ndarray>
#     AHRSGyroY                  (time) float32 dask.array<chunksize=(148123,), meta=np.ndarray>
#     AHRSGyroZ                  (time) float32 dask.array<chunksize=(148123,), meta=np.ndarray>
# Attributes: (12/350)
#     exportRevision:                               4421
#     File_ins_runTime:                             373714906.0
#     File_ins_runTime_description:                 Length of time data was col...
#     File_ins_name:                                AD2CPRaw
#     File_ins_name_description:                    Name of instrument
#     File_ins_typeName:
#     ...                                           ...
#     instrumentOffsetTime:                         0.0
#     instrumentOffsetTime_description:             Offset from instrument time...
#     timeZoneOffset:                               -18000
#     timeZoneOffset_description:                   Offset of platform local ti...
#     instrumentOffsetTimeMatlab:                   0.0
#     instrumentOffsetTimeMatlab_description:       Offset from instrument time...

# %% [markdown]
# ## Steps 3-10: Big loop to process velocity data and save output

# %%
#for x in np.arange(0,len(start_times)):
## Weird this one crashed on 156 too
for x in np.arange(156,len(start_times)):
   
    ## Subset glider df to one segment
    subsetgdf = gdf[(gdf.time >= start_times[x]) & (gdf.time <= end_times[x])]
    ## Pull out last non-NaN DAC
    ind         = np.argwhere(np.isnan(subsetgdf.m_water_vx).ravel()==False).flatten()
    vx          = subsetgdf.m_water_vx.iloc[ind[-1]]
    vy          = subsetgdf.m_water_vy.iloc[ind[-1]]
    
    ## Pull out last non-NaN lat/lon
    ind1         = np.argwhere(np.isnan(subsetgdf.longitude).ravel()==False).flatten()   
    vx_start_lon = subsetgdf.longitude.iloc[ind1[0]]
    vx_start_lat = subsetgdf.latitude.iloc[ind1[0]]
    vx_end_lon   = subsetgdf.longitude.iloc[ind1[-1]]
    vx_end_lat   = subsetgdf.latitude.iloc[ind1[-1]]
    ## Not using the index here because I want the segment start and end times
    vx_start_tm  = subsetgdf.time.iloc[0]
    vx_end_tm    = subsetgdf.time.iloc[-1]
    
    ## Check is glider has a max depth greater than 10 meters. If not, continue to next segment.
    ## This is needed because the glider opens and closes a log file at the surface while sending data and
    ## so indexing by unique file names gives a segment with just surface data (which we don't want).
    if subsetgdf.depth.max() < 10:
        continue
    
    ## Subset AD2CP dataframe based on segment start and end times
    ad2cp_time_ind = np.where((tot_ad2cp.time >= start_times2[x]) & (tot_ad2cp.time <= end_times2[x]))[0]
    subset_ad2cp = tot_ad2cp.sel(time=tot_ad2cp.time[ad2cp_time_ind])
    
    ## Just check if there is still data after the subsetting 
    if len(subset_ad2cp.time) > 0:
        ## Now process AD2CP!

        ## Correct for local speed of sound
        subset_ad2cp = correct_sound_speed(subset_ad2cp)
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished Sound Speed Correction", x ,"out of",len(start_times),"at" ,now)

        ## QAQC pre-coordinate transformation
        subset_ad2cp = qaqc_pre_coord_transform(subset_ad2cp)
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished QAQC", x ,"out of",len(start_times),"at" ,now)

        ## Correct beams to level true-depth
        subset_ad2cp = beam_true_depth(subset_ad2cp)
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished Beam to True Depth", x ,"out of",len(start_times),"at" ,now)

        ## Bin map
        subset_ad2cp = binmap_adcp(subset_ad2cp)
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished Bin Mapping", x ,"out of",len(start_times),"at" ,now)

        ## Beam to ENU
        subset_ad2cp = beam2enu(subset_ad2cp)
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished Beam to ENU", x ,"out of",len(start_times),"at" ,now)

        ## Filter out really high velocities relative to glider
        subset_ad2cp.UVelocity.values[subset_ad2cp.UVelocity>0.5] = np.NaN
        subset_ad2cp.VVelocity.values[subset_ad2cp.VVelocity>0.5] = np.NaN
        subset_ad2cp.WVelocity.values[subset_ad2cp.WVelocity>0.5] = np.NaN
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished Filtering High Velocities", x ,"out of",len(start_times),"at" ,now)

        # ## Now ready for inversion!
        O_ls, G_ls, bin_new = inversion(U=subset_ad2cp.UVelocity.transpose().values,V=subset_ad2cp.VVelocity.transpose().values,H=1000,dz=5,u_daverage=vx,v_daverage=vy,bins = subset_ad2cp['VelocityRange'], depth = subset_ad2cp['Pressure'])
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished Inversion", x ,"out of",len(start_times),"at" ,now)

        ###############################################
        #             Save master dataset             #
        ###############################################
        fname = "/home/jg1200/Data/GliderData/RU29/RU29_2021_Mission_2_AD2CP_NC/Processed/RU29_2021_Mission_2_AD2CP_Processed_Segment_{}.csv".format(x)
        ## Make into a dataframe to save as a CSV
        d = {'inversion_u': np.real(O_ls), 'inversion_v': np.imag(O_ls), "inversion_depth": bin_new,
             "start_lon": np.tile(vx_start_lon,len(bin_new)), "start_lat": np.tile(vx_start_lat,len(bin_new)),
             "end_lon": np.tile(vx_end_lon,len(bin_new)), "end_lat": np.tile(vx_end_lat,len(bin_new)),
             "start_tm": np.tile(vx_start_tm, len(bin_new)), "end_tm": np.tile(vx_end_tm, len(bin_new))}

        df = pd.DataFrame(data=d)
        df.to_csv(fname) 
        now = datetime.now().strftime("%m/%d/%y %H:%M:%S")
        print("Finished Writing Data", x ,"out of",len(start_times),"at" ,now)
        del subset_ad2cp
    else:
        del subset_ad2cp
# Out:
# Finished Sound Speed Correction 156 out of 429 at 03/16/22 15:37:11
# Finished QAQC 156 out of 429 at 03/16/22 15:37:12
# Finished Beam to True Depth 156 out of 429 at 03/16/22 15:37:15
# Finished Bin Mapping 156 out of 429 at 03/16/22 15:37:16
# Finished Beam to ENU 156 out of 429 at 03/16/22 15:40:51
# Finished Filtering High Velocities 156 out of 429 at 03/16/22 15:40:51
# Finished Inversion 156 out of 429 at 03/16/22 15:42:22
# Finished Writing Data 156 out of 429 at 03/16/22 15:42:22
# Finished Sound Speed Correction 158 out of 429 at 03/16/22 15:42:24
# Finished QAQC 158 out of 429 at 03/16/22 15:42:24
# Finished Beam to True Depth 158 out of 429 at 03/16/22 15:42:27
# Finished Bin Mapping 158 out of 429 at 03/16/22 15:42:28
# Finished Beam to ENU 158 out of 429 at 03/16/22 15:46:01
# Finished Filtering High Velocities 158 out of 429 at 03/16/22 15:46:01
# Finished Inversion 158 out of 429 at 03/16/22 15:47:34
# Finished Writing Data 158 out of 429 at 03/16/22 15:47:34
# Finished Sound Speed Correction 160 out of 429 at 03/16/22 15:47:36
# Finished QAQC 160 out of 429 at 03/16/22 15:47:36
# Finished Beam to True Depth 160 out of 429 at 03/16/22 15:47:39
# Finished Bin Mapping 160 out of 429 at 03/16/22 15:47:40
# Finished Beam to ENU 160 out of 429 at 03/16/22 15:51:28
# Finished Filtering High Velocities 160 out of 429 at 03/16/22 15:51:28
# Finished Inversion 160 out of 429 at 03/16/22 15:53:04
# Finished Writing Data 160 out of 429 at 03/16/22 15:53:04
# Finished Sound Speed Correction 162 out of 429 at 03/16/22 15:53:05
# Finished QAQC 162 out of 429 at 03/16/22 15:53:06
# Finished Beam to True Depth 162 out of 429 at 03/16/22 15:53:08
# Finished Bin Mapping 162 out of 429 at 03/16/22 15:53:09
# Finished Beam to ENU 162 out of 429 at 03/16/22 15:56:40
# Finished Filtering High Velocities 162 out of 429 at 03/16/22 15:56:40
# Finished Inversion 162 out of 429 at 03/16/22 15:58:09
# Finished Writing Data 162 out of 429 at 03/16/22 15:58:09
# Finished Sound Speed Correction 164 out of 429 at 03/16/22 15:58:11
# Finished QAQC 164 out of 429 at 03/16/22 15:58:12
# Finished Beam to True Depth 164 out of 429 at 03/16/22 15:58:14
# Finished Bin Mapping 164 out of 429 at 03/16/22 15:58:15
# Finished Beam to ENU 164 out of 429 at 03/16/22 16:01:43
# Finished Filtering High Velocities 164 out of 429 at 03/16/22 16:01:43
# Finished Inversion 164 out of 429 at 03/16/22 16:03:11
# Finished Writing Data 164 out of 429 at 03/16/22 16:03:11
# Finished Sound Speed Correction 165 out of 429 at 03/16/22 16:03:13
# Finished QAQC 165 out of 429 at 03/16/22 16:03:14
# Finished Beam to True Depth 165 out of 429 at 03/16/22 16:03:16
# Finished Bin Mapping 165 out of 429 at 03/16/22 16:03:17
# Finished Beam to ENU 165 out of 429 at 03/16/22 16:06:45
# Finished Filtering High Velocities 165 out of 429 at 03/16/22 16:06:45
# Finished Inversion 165 out of 429 at 03/16/22 16:08:14
# Finished Writing Data 165 out of 429 at 03/16/22 16:08:14
# Finished Sound Speed Correction 167 out of 429 at 03/16/22 16:08:15
# Finished QAQC 167 out of 429 at 03/16/22 16:08:16
# Finished Beam to True Depth 167 out of 429 at 03/16/22 16:08:18
# Finished Bin Mapping 167 out of 429 at 03/16/22 16:08:19
# Finished Beam to ENU 167 out of 429 at 03/16/22 16:11:45
# Finished Filtering High Velocities 167 out of 429 at 03/16/22 16:11:45
# Finished Inversion 167 out of 429 at 03/16/22 16:13:13
# Finished Writing Data 167 out of 429 at 03/16/22 16:13:13
# Finished Sound Speed Correction 169 out of 429 at 03/16/22 16:13:15
# Finished QAQC 169 out of 429 at 03/16/22 16:13:16
# Finished Beam to True Depth 169 out of 429 at 03/16/22 16:13:18
# Finished Bin Mapping 169 out of 429 at 03/16/22 16:13:19
# Finished Beam to ENU 169 out of 429 at 03/16/22 16:16:51
# Finished Filtering High Velocities 169 out of 429 at 03/16/22 16:16:51
# Finished Inversion 169 out of 429 at 03/16/22 16:18:21
# Finished Writing Data 169 out of 429 at 03/16/22 16:18:21
# Finished Sound Speed Correction 171 out of 429 at 03/16/22 16:18:23
# Finished QAQC 171 out of 429 at 03/16/22 16:18:23
# Finished Beam to True Depth 171 out of 429 at 03/16/22 16:18:26
# Finished Bin Mapping 171 out of 429 at 03/16/22 16:18:27
# Finished Beam to ENU 171 out of 429 at 03/16/22 16:22:03
# Finished Filtering High Velocities 171 out of 429 at 03/16/22 16:22:03
# Finished Inversion 171 out of 429 at 03/16/22 16:23:37
# Finished Writing Data 171 out of 429 at 03/16/22 16:23:37
# Finished Sound Speed Correction 172 out of 429 at 03/16/22 16:23:38
# Finished QAQC 172 out of 429 at 03/16/22 16:23:39
# Finished Beam to True Depth 172 out of 429 at 03/16/22 16:23:41
# Finished Bin Mapping 172 out of 429 at 03/16/22 16:23:42
# Finished Beam to ENU 172 out of 429 at 03/16/22 16:27:04
# Finished Filtering High Velocities 172 out of 429 at 03/16/22 16:27:04
# Finished Inversion 172 out of 429 at 03/16/22 16:28:33
# Finished Writing Data 172 out of 429 at 03/16/22 16:28:33
# Finished Sound Speed Correction 174 out of 429 at 03/16/22 16:28:35
# Finished QAQC 174 out of 429 at 03/16/22 16:28:35
# Finished Beam to True Depth 174 out of 429 at 03/16/22 16:28:38
# Finished Bin Mapping 174 out of 429 at 03/16/22 16:28:39
# Finished Beam to ENU 174 out of 429 at 03/16/22 16:32:10
# Finished Filtering High Velocities 174 out of 429 at 03/16/22 16:32:10
# Finished Inversion 174 out of 429 at 03/16/22 16:33:41
# Finished Writing Data 174 out of 429 at 03/16/22 16:33:41
# Finished Sound Speed Correction 177 out of 429 at 03/16/22 16:33:42
# Finished QAQC 177 out of 429 at 03/16/22 16:33:43
# Finished Beam to True Depth 177 out of 429 at 03/16/22 16:33:45
# Finished Bin Mapping 177 out of 429 at 03/16/22 16:33:46
# Finished Beam to ENU 177 out of 429 at 03/16/22 16:37:16
# Finished Filtering High Velocities 177 out of 429 at 03/16/22 16:37:16
# Finished Inversion 177 out of 429 at 03/16/22 16:38:47
# Finished Writing Data 177 out of 429 at 03/16/22 16:38:47
# Finished Sound Speed Correction 179 out of 429 at 03/16/22 16:38:49
# Finished QAQC 179 out of 429 at 03/16/22 16:38:50
# Finished Beam to True Depth 179 out of 429 at 03/16/22 16:38:52
# Finished Bin Mapping 179 out of 429 at 03/16/22 16:38:53
# Finished Beam to ENU 179 out of 429 at 03/16/22 16:42:18
# Finished Filtering High Velocities 179 out of 429 at 03/16/22 16:42:18
# Finished Inversion 179 out of 429 at 03/16/22 16:43:48
# Finished Writing Data 179 out of 429 at 03/16/22 16:43:48
# Finished Sound Speed Correction 181 out of 429 at 03/16/22 16:43:50
# Finished QAQC 181 out of 429 at 03/16/22 16:43:51
# Finished Beam to True Depth 181 out of 429 at 03/16/22 16:43:53
# Finished Bin Mapping 181 out of 429 at 03/16/22 16:43:54
# Finished Beam to ENU 181 out of 429 at 03/16/22 16:47:13
# Finished Filtering High Velocities 181 out of 429 at 03/16/22 16:47:13
# Finished Inversion 181 out of 429 at 03/16/22 16:48:41
# Finished Writing Data 181 out of 429 at 03/16/22 16:48:41
# Finished Sound Speed Correction 183 out of 429 at 03/16/22 16:48:43
# Finished QAQC 183 out of 429 at 03/16/22 16:48:43
# Finished Beam to True Depth 183 out of 429 at 03/16/22 16:48:46
# Finished Bin Mapping 183 out of 429 at 03/16/22 16:48:47
# Finished Beam to ENU 183 out of 429 at 03/16/22 16:52:16
# Finished Filtering High Velocities 183 out of 429 at 03/16/22 16:52:16
# Finished Inversion 183 out of 429 at 03/16/22 16:53:47
# Finished Writing Data 183 out of 429 at 03/16/22 16:53:47
# Finished Sound Speed Correction 185 out of 429 at 03/16/22 16:53:49
# Finished QAQC 185 out of 429 at 03/16/22 16:53:50
# Finished Beam to True Depth 185 out of 429 at 03/16/22 16:53:52
# Finished Bin Mapping 185 out of 429 at 03/16/22 16:53:53
# Finished Beam to ENU 185 out of 429 at 03/16/22 16:57:18
# Finished Filtering High Velocities 185 out of 429 at 03/16/22 16:57:18
# Finished Inversion 185 out of 429 at 03/16/22 16:58:47
# Finished Writing Data 185 out of 429 at 03/16/22 16:58:47
# Finished Sound Speed Correction 186 out of 429 at 03/16/22 16:58:48
# Finished QAQC 186 out of 429 at 03/16/22 16:58:50
# Finished Beam to True Depth 186 out of 429 at 03/16/22 16:58:52
# Finished Bin Mapping 186 out of 429 at 03/16/22 16:58:53
# Finished Beam to ENU 186 out of 429 at 03/16/22 17:02:10
# Finished Filtering High Velocities 186 out of 429 at 03/16/22 17:02:10
# Finished Inversion 186 out of 429 at 03/16/22 17:03:36
# Finished Writing Data 186 out of 429 at 03/16/22 17:03:36
# Finished Sound Speed Correction 188 out of 429 at 03/16/22 17:03:38
# Finished QAQC 188 out of 429 at 03/16/22 17:03:38
# Finished Beam to True Depth 188 out of 429 at 03/16/22 17:03:41
# Finished Bin Mapping 188 out of 429 at 03/16/22 17:03:42
# Finished Beam to ENU 188 out of 429 at 03/16/22 17:07:03
# Finished Filtering High Velocities 188 out of 429 at 03/16/22 17:07:03
# Finished Inversion 188 out of 429 at 03/16/22 17:08:32
# Finished Writing Data 188 out of 429 at 03/16/22 17:08:32
# Finished Sound Speed Correction 190 out of 429 at 03/16/22 17:08:34
# Finished QAQC 190 out of 429 at 03/16/22 17:08:34
# Finished Beam to True Depth 190 out of 429 at 03/16/22 17:08:37
# Finished Bin Mapping 190 out of 429 at 03/16/22 17:08:38
# Finished Beam to ENU 190 out of 429 at 03/16/22 17:11:58
# Finished Filtering High Velocities 190 out of 429 at 03/16/22 17:11:58
# Finished Inversion 190 out of 429 at 03/16/22 17:13:26
# Finished Writing Data 190 out of 429 at 03/16/22 17:13:26
# Finished Sound Speed Correction 192 out of 429 at 03/16/22 17:13:28
# Finished QAQC 192 out of 429 at 03/16/22 17:13:28
# Finished Beam to True Depth 192 out of 429 at 03/16/22 17:13:31
# Finished Bin Mapping 192 out of 429 at 03/16/22 17:13:32
# Finished Beam to ENU 192 out of 429 at 03/16/22 17:17:00
# Finished Filtering High Velocities 192 out of 429 at 03/16/22 17:17:00
# Finished Inversion 192 out of 429 at 03/16/22 17:18:30
# Finished Writing Data 192 out of 429 at 03/16/22 17:18:30
# Finished Sound Speed Correction 194 out of 429 at 03/16/22 17:18:32
# Finished QAQC 194 out of 429 at 03/16/22 17:18:33
# Finished Beam to True Depth 194 out of 429 at 03/16/22 17:18:35
# Finished Bin Mapping 194 out of 429 at 03/16/22 17:18:36
# Finished Beam to ENU 194 out of 429 at 03/16/22 17:22:01
# Finished Filtering High Velocities 194 out of 429 at 03/16/22 17:22:02
# Finished Inversion 194 out of 429 at 03/16/22 17:23:31
# Finished Writing Data 194 out of 429 at 03/16/22 17:23:31
# Finished Sound Speed Correction 196 out of 429 at 03/16/22 17:23:32
# Finished QAQC 196 out of 429 at 03/16/22 17:23:33
# Finished Beam to True Depth 196 out of 429 at 03/16/22 17:23:35
# Finished Bin Mapping 196 out of 429 at 03/16/22 17:23:36
# Finished Beam to ENU 196 out of 429 at 03/16/22 17:26:53
# Finished Filtering High Velocities 196 out of 429 at 03/16/22 17:26:53
# Finished Inversion 196 out of 429 at 03/16/22 17:28:19
# Finished Writing Data 196 out of 429 at 03/16/22 17:28:19
# Finished Sound Speed Correction 199 out of 429 at 03/16/22 17:28:21
# Finished QAQC 199 out of 429 at 03/16/22 17:28:21
# Finished Beam to True Depth 199 out of 429 at 03/16/22 17:28:24
# Finished Bin Mapping 199 out of 429 at 03/16/22 17:28:25
# Finished Beam to ENU 199 out of 429 at 03/16/22 17:31:53
# Finished Filtering High Velocities 199 out of 429 at 03/16/22 17:31:53
# Finished Inversion 199 out of 429 at 03/16/22 17:33:23
# Finished Writing Data 199 out of 429 at 03/16/22 17:33:24
# Finished Sound Speed Correction 201 out of 429 at 03/16/22 17:33:25
# Finished QAQC 201 out of 429 at 03/16/22 17:33:26
# Finished Beam to True Depth 201 out of 429 at 03/16/22 17:33:28
# Finished Bin Mapping 201 out of 429 at 03/16/22 17:33:29
# Finished Beam to ENU 201 out of 429 at 03/16/22 17:36:52
# Finished Filtering High Velocities 201 out of 429 at 03/16/22 17:36:52
# Finished Inversion 201 out of 429 at 03/16/22 17:38:20
# Finished Writing Data 201 out of 429 at 03/16/22 17:38:20
# Finished Sound Speed Correction 203 out of 429 at 03/16/22 17:38:21
# Finished QAQC 203 out of 429 at 03/16/22 17:38:22
# Finished Beam to True Depth 203 out of 429 at 03/16/22 17:38:24
# Finished Bin Mapping 203 out of 429 at 03/16/22 17:38:25
# Finished Beam to ENU 203 out of 429 at 03/16/22 17:41:45
# Finished Filtering High Velocities 203 out of 429 at 03/16/22 17:41:45
# Finished Inversion 203 out of 429 at 03/16/22 17:43:12
# Finished Writing Data 203 out of 429 at 03/16/22 17:43:12
# Finished Sound Speed Correction 205 out of 429 at 03/16/22 17:43:13
# Finished QAQC 205 out of 429 at 03/16/22 17:43:14
# Finished Beam to True Depth 205 out of 429 at 03/16/22 17:43:16
# Finished Bin Mapping 205 out of 429 at 03/16/22 17:43:17
# Finished Beam to ENU 205 out of 429 at 03/16/22 17:46:42
# Finished Filtering High Velocities 205 out of 429 at 03/16/22 17:46:42
# Finished Inversion 205 out of 429 at 03/16/22 17:48:10
# Finished Writing Data 205 out of 429 at 03/16/22 17:48:10
# Finished Sound Speed Correction 207 out of 429 at 03/16/22 17:48:12
# Finished QAQC 207 out of 429 at 03/16/22 17:48:12
# Finished Beam to True Depth 207 out of 429 at 03/16/22 17:48:15
# Finished Bin Mapping 207 out of 429 at 03/16/22 17:48:16
# Finished Beam to ENU 207 out of 429 at 03/16/22 17:51:45
# Finished Filtering High Velocities 207 out of 429 at 03/16/22 17:51:45
# Finished Inversion 207 out of 429 at 03/16/22 17:53:15
# Finished Writing Data 207 out of 429 at 03/16/22 17:53:15
# Finished Sound Speed Correction 208 out of 429 at 03/16/22 17:53:17
# Finished QAQC 208 out of 429 at 03/16/22 17:53:17
# Finished Beam to True Depth 208 out of 429 at 03/16/22 17:53:17
# Finished Bin Mapping 208 out of 429 at 03/16/22 17:53:17
# Finished Beam to ENU 208 out of 429 at 03/16/22 17:53:40
# Finished Filtering High Velocities 208 out of 429 at 03/16/22 17:53:40
# Finished Inversion 208 out of 429 at 03/16/22 17:53:43
# Finished Writing Data 208 out of 429 at 03/16/22 17:53:43
# Finished Sound Speed Correction 210 out of 429 at 03/16/22 17:53:45
# Finished QAQC 210 out of 429 at 03/16/22 17:53:45
# Finished Beam to True Depth 210 out of 429 at 03/16/22 17:53:45
# Finished Bin Mapping 210 out of 429 at 03/16/22 17:53:45
# Finished Beam to ENU 210 out of 429 at 03/16/22 17:54:02
# Finished Filtering High Velocities 210 out of 429 at 03/16/22 17:54:02
# Finished Inversion 210 out of 429 at 03/16/22 17:54:06
# Finished Writing Data 210 out of 429 at 03/16/22 17:54:06
# Finished Sound Speed Correction 211 out of 429 at 03/16/22 17:54:07
# Finished QAQC 211 out of 429 at 03/16/22 17:54:07
# Finished Beam to True Depth 211 out of 429 at 03/16/22 17:54:08
# Finished Bin Mapping 211 out of 429 at 03/16/22 17:54:08

# %% [markdown]
# ## Take a quick peak at results. Actual analysis in different notebook

# %%
path = "/home/jg1200/Data/GliderData/RU29/RU29_2021_Mission_2_AD2CP_NC/Processed/"
files = np.sort(glob.glob(path+'*.csv'))

df = pd.concat(map(pd.read_csv, files))

df

# %%
inversion_depth   = np.arange(5,1030,10)
inversion_lat    = np.empty(len(files))
inversion_lat[:] = np.NaN
inversion_lon    = np.empty(len(files))
inversion_lon[:] = np.NaN
inversion_time    = np.empty(len(files))
inversion_time[:] = np.NaN

u_grid = np.empty((len(inversion_depth),len(files)))
u_grid[:] = np.NaN
v_grid = np.empty((len(inversion_depth),len(files)))
v_grid[:] = np.NaN


## Loop through by file, load in each file
for x in np.arange(0,len(files)):
    
    df = pd.read_csv(files[x])
    u_grid[np.arange(0,len(df.inversion_u.values)),x] = df.inversion_u.values
    v_grid[np.arange(0,len(df.inversion_v.values)),x] = df.inversion_v.values
    inversion_lat[x] = df.latitude.values[0]
    inversion_lon[x] = df.longitude.values[0]
    #inversion_time[x] = pd.to_datetime(df.start_tm.values[0])

# %%
plt.figure(figsize=(18,10))
plt.pcolormesh(u_grid,cmap='RdBu',vmin=-0.4,vmax=0.4)
plt.gca().invert_yaxis()
plt.colorbar(label='E-W Velocity [m/s]')
plt.title('RU29 2021 Anegada Mission 2')

# %%
plt.figure(figsize=(18,10))
plt.pcolormesh(v_grid,cmap='RdBu',vmin=-0.4,vmax=0.4)
plt.gca().invert_yaxis()
plt.colorbar(label='N-S Velocity [m/s]')
plt.title('RU29 2021 Anegada Mission 2')
